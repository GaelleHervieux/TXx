# %% [markdown]
# ##
# CONUS
#
# Plots Comparisons
#
# Evgam vs extRemes

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import scipy
import cftime
import cartopy
import cartopy.crs as ccrs
import matplotlib.colors as colors
import cmaps
from xhistogram.xarray import histogram
from statsmodels.nonparametric.smoothers_lowess import lowess as  sm_lowess
from copy import copy
import geopandas as gpd
from shapely.geometry import Point

# %%
state_borders =\
cartopy.feature.NaturalEarthFeature(category='cultural',\
        name='admin_1_states_provinces_lakes', scale='50m', facecolor='none')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # READ EVGAM output FILES

# %%
yearb=1979
yeare=2025
lon_min = 235
lon_max = 293
lat_min = 25
lat_max = 50

dirin =''

ds0 = xr.open_dataset(f'{dirin}/TXx_CONUS_ij_glost_extremes_1941_2025.nc')
rl1000 = ds0['rl100']
loc0 = ds0['location'] 
scale0 = ds0['scale'] 
shape0 = ds0['shape'] 
pvalue0 = ds0['pvalue'] 


ds1 = xr.open_dataset(f'{dirin}/TXx_CONUS_ij_glost_extremes_1979_2025.nc')
rl1001 = ds1['rl100']
loc1 = ds1['location'] 
scale1 = ds1['scale'] 
shape1 = ds1['shape'] 
pvalue1 = ds1['pvalue'] 

ds2 = xr.open_dataset(f'{dirin}/TXx_Alaska_ij_glost_extremes_1941_2025.nc')
rl1002 = ds2['rl100']
loc2 = ds2['location'] 
scale2 = ds2['scale'] 
shape2 = ds2['shape'] 
pvalue2 = ds2['pvalue'] 


ds3 = xr.open_dataset(f'{dirin}/TXx_Alaska_ij_glost_extremes_1979_2025.nc')
rl1003 = ds3['rl100']
loc3 = ds3['location'] 
scale3 = ds3['scale'] 
shape3 = ds3['shape'] 
pvalue3 = ds3['pvalue'] 

units = '°F'

Tlabels = ['extRemes 1941-2025 (time covariate)','extRemes 1979-2025 (time covariate)',
           'extRemes 1941-2025 (time covariate)','extRemes 1979-2025 (time covariate)']

# %%
Trl100 = [rl1000,rl1001,rl1002,rl1003]
Tloc = [loc0,loc1,loc2,loc3]
Tscale = [scale0,scale1,scale2,scale3]
Tshape = [shape0,shape1,shape2,shape3]
Tpvalue = [pvalue0,pvalue1,pvalue2,pvalue3]
#

# %%
fileGLOST = '/annual_LOESS_NOAA_GLOST_anomaly.nc'
ds_glost=xr.open_dataset(fileGLOST)

ann_glost = ds_glost['glost']

# %%
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(14,5))
ann_glost.plot(ax=ax)
ax.axvline(1941,c='k',lw=2.,ls='--')
ax.axvline(1979,c='k',lw=2.,ls='--')
ax.text(1941,1.05,' 1941',fontsize=16)
ax.text(1979,1.05,' 1979',fontsize=16)
ax.grid()
ax.tick_params(axis='both', labelsize=14)
ax.set_xlabel('time',fontsize=16)
ax.set_ylabel('$\degree$C',fontsize=16)
plt.title('GLOST LOESS',fontsize=20)
# Out:
# Text(0.5, 1.0, 'GLOST LOESS')

# %% [markdown]
# # PLOT Return Level 100

# %%
clevs = np.arange(30,140,5)
cmap = plt.get_cmap(cmaps.amwg,len(clevs)).copy()

proj=ccrs.PlateCarree()
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.25,left=0.1, right=0.9,top=0.95,hspace=0.04,wspace=0.04)
ax = ax.flatten()
for ix in range(0,len(Tloc)):
  cc = Trl100[ix].sel(time=yearb).plot.pcolormesh(ax=ax[ix],cmap=cmap,vmin=clevs[0],vmax=clevs[-1],add_colorbar=False)
  ####
for ix in range(0,len(Tloc)):
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')
  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

for ix in range(0,1): 
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label='',fontsize=16)
#
#
plt.suptitle(f'Return Level 100year: {yearb}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Return Level 100year: 1979')

# %%
clevs = np.arange(30,140,5)
cmap = plt.get_cmap(cmaps.amwg,len(clevs)).copy()

proj=ccrs.PlateCarree()
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.25,left=0.1, right=0.9,top=0.95,hspace=0.04,wspace=0.04)
ax = ax.flatten()
for ix in range(0,len(Tloc)):
  cc = Trl100[ix].sel(time=yeare).plot.pcolormesh(ax=ax[ix],cmap=cmap,vmin=clevs[0],vmax=clevs[-1],add_colorbar=False)
  ####
for ix in range(0,len(Tloc)):
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')
  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

for ix in range(0,1): 
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label='',fontsize=16)
#
#
plt.suptitle(f'Return Level 100year: {yeare}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Return Level 100year: 2025')

# %%
clevs = np.arange(-20,22,2)
cmap = plt.get_cmap('seismic',len(clevs)).copy()

proj=ccrs.PlateCarree()
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.25,left=0.1, right=0.9,top=0.95,hspace=0.04,wspace=0.04)
ax = ax.flatten()
for ix in range(0,len(Tloc)):
  cc = (Trl100[ix].sel(time=yeare)-Trl100[ix].sel(time=yearb)).plot.pcolormesh(ax=ax[ix],cmap=cmap,vmin=clevs[0],vmax=clevs[-1],add_colorbar=False)

####
for ix in range(0,len(Tloc)):  
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')
 
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)    


for ix in range(0,1,2): 
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
#

#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.set_label(label=units,fontsize=16)
plt.suptitle(f'Return Level 100year, Difference {yeare} - {yearb}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Return Level 100year, Difference 2025 - 1979')

# %%
clevs = np.arange(30,140,5)
cmap = plt.get_cmap(cmaps.amwg,len(clevs)).copy()

proj=ccrs.PlateCarree()
#clevs = np.arange(0,12,.5)
cmap = plt.get_cmap(cmaps.amwg,len(clevs)).copy()

proj=ccrs.PlateCarree()

#
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.25,left=0.1, right=0.9,top=0.95,hspace=0.04,wspace=0.04)
ax = ax.flatten()
for ix in range(0,len(Tloc)):
  cc = Trl100[ix].sel(time=yearb).plot.pcolormesh(ax=ax[ix],cmap=cmap,vmin=clevs[0],vmax=clevs[-1],add_colorbar=False)
  ####
for ix in range(0,len(Tloc)):
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')
  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

for ix in range(0,1): 
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label='',fontsize=16)
#

#
plt.suptitle(f'Location parameter: {yearb}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Location parameter: 1979')

# %%
clevs = np.arange(30,140,5)
cmap = plt.get_cmap(cmaps.amwg,len(clevs)).copy()

proj=ccrs.PlateCarree()
#clevs = np.arange(0,12,.5)
cmap = plt.get_cmap(cmaps.amwg,len(clevs)).copy()

proj=ccrs.PlateCarree()

#
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.25,left=0.1, right=0.9,top=0.95,hspace=0.04,wspace=0.04)
ax = ax.flatten()
for ix in range(0,len(Tloc)):
  cc = Trl100[ix].sel(time=yearb).plot.pcolormesh(ax=ax[ix],cmap=cmap,vmin=clevs[0],vmax=clevs[-1],add_colorbar=False)
  ####
for ix in range(0,len(Tloc)):
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')
  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

for ix in range(0,1): 
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label='',fontsize=16)
#

#
plt.suptitle(f'Location parameter: {yeare}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Location parameter: 2025')

# %%
clevs = np.arange(0,10,.5)
cmap = plt.get_cmap(cmaps.amwg,len(clevs)).copy()

proj=ccrs.PlateCarree()

#
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.25,left=0.1, right=0.9,top=0.95,hspace=0.04,wspace=0.04)
ax = ax.flatten()
for ix in range(0,len(Tloc)):
  cc = Tscale[ix].sel(time=yearb).plot.pcolormesh(ax=ax[ix],cmap=cmap,vmin=clevs[0],vmax=clevs[-1],add_colorbar=False)
  ####
for ix in range(0,len(Tloc)):
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')
  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

for ix in range(0,1): 
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label='',fontsize=16)
#

#
plt.suptitle(f'Scale parameter {yearb}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Scale parameter 1979')

# %%
clevs = np.arange(0,10,.5)
cmap = plt.get_cmap(cmaps.amwg,len(clevs)).copy()

proj=ccrs.PlateCarree()

#
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.25,left=0.1, right=0.9,top=0.95,hspace=0.04,wspace=0.04)
ax = ax.flatten()
for ix in range(0,len(Tloc)):
  cc = Tscale[ix].sel(time=yeare).plot.pcolormesh(ax=ax[ix],cmap=cmap,vmin=clevs[0],vmax=clevs[-1],add_colorbar=False)

  ####
for ix in range(0,len(Tloc)):
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')
  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

for ix in range(0,1): 
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label='',fontsize=16)
#

#
plt.suptitle(f'Scale parameter {yeare}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Scale parameter 2025')

# %%
clevs = np.arange(-0.65,0.75,0.05)
cmap = plt.get_cmap(cmaps.ncl_default,len(clevs)).copy()

proj=ccrs.PlateCarree()

fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.25,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.01)
ax = ax.flatten()
for ix in range(0,len(Tloc)): 
  cc = Tshape[ix].sel(time=yearb).plot.pcolormesh(ax=ax[ix],cmap=cmap,levels=clevs,add_colorbar=False)

for ix in range(0,len(Tloc)):
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')
  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

for ix in range(0,1): 
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label='',fontsize=16)
#

plt.suptitle(f'Shape parameter, year={yearb}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Shape parameter, year=1979')

# %%
Tshape[0].lon.data
# Out:
# array([235.  , 235.25, 235.5 , 235.75, 236.  , 236.25, 236.5 , 236.75,
#        237.  , 237.25, 237.5 , 237.75, 238.  , 238.25, 238.5 , 238.75,
#        239.  , 239.25, 239.5 , 239.75, 240.  , 240.25, 240.5 , 240.75,
#        241.  , 241.25, 241.5 , 241.75, 242.  , 242.25, 242.5 , 242.75,
#        243.  , 243.25, 243.5 , 243.75, 244.  , 244.25, 244.5 , 244.75,
#        245.  , 245.25, 245.5 , 245.75, 246.  , 246.25, 246.5 , 246.75,
#        247.  , 247.25, 247.5 , 247.75, 248.  , 248.25, 248.5 , 248.75,
#        249.  , 249.25, 249.5 , 249.75, 250.  , 250.25, 250.5 , 250.75,
#        251.  , 251.25, 251.5 , 251.75, 252.  , 252.25, 252.5 , 252.75,
#        253.  , 253.25, 253.5 , 253.75, 254.  , 254.25, 254.5 , 254.75,
#        255.  , 255.25, 255.5 , 255.75, 256.  , 256.25, 256.5 , 256.75,
#        257.  , 257.25, 257.5 , 257.75, 258.  , 258.25, 258.5 , 258.75,
#        259.  , 259.25, 259.5 , 259.75, 260.  , 260.25, 260.5 , 260.75,
#        261.  , 261.25, 261.5 , 261.75, 262.  , 262.25, 262.5 , 262.75,
#        263.  , 263.25, 263.5 , 263.75, 264.  , 264.25, 264.5 , 264.75,
#        265.  , 265.25, 265.5 , 265.75, 266.  , 266.25, 266.5 , 266.75,
#        267.  , 267.25, 267.5 , 267.75, 268.  , 268.25, 268.5 , 268.75,
#        269.  , 269.25, 269.5 , 269.75, 270.  , 270.25, 270.5 , 270.75,
#        271.  , 271.25, 271.5 , 271.75, 272.  , 272.25, 272.5 , 272.75,
#        273.  , 273.25, 273.5 , 273.75, 274.  , 274.25, 274.5 , 274.75,
#        275.  , 275.25, 275.5 , 275.75, 276.  , 276.25, 276.5 , 276.75,
#        277.  , 277.25, 277.5 , 277.75, 278.  , 278.25, 278.5 , 278.75,
#        279.  , 279.25, 279.5 , 279.75, 280.  , 280.25, 280.5 , 280.75,
#        281.  , 281.25, 281.5 , 281.75, 282.  , 282.25, 282.5 , 282.75,
#        283.  , 283.25, 283.5 , 283.75, 284.  , 284.25, 284.5 , 284.75,
#        285.  , 285.25, 285.5 , 285.75, 286.  , 286.25, 286.5 , 286.75,
#        287.  , 287.25, 287.5 , 287.75, 288.  , 288.25, 288.5 , 288.75,
#        289.  , 289.25, 289.5 , 289.75, 290.  , 290.25, 290.5 , 290.75,
#        291.  , 291.25, 291.5 , 291.75, 292.  , 292.25, 292.5 , 292.75,
#        293.  ])

# %%
clevs = np.arange(-0.65,0.75,0.05)
cmap = plt.get_cmap(cmaps.ncl_default,len(clevs)).copy()

proj=ccrs.PlateCarree()

fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.25,left=0.1, right=0.9,top=0.9,hspace=0.01,wspace=0.01)
ax = ax.flatten()
for ix in range(0,len(Tloc[0:2])): 
  cc = Tshape[ix].sel(time=yearb).sel(lon=slice(235,245)).plot.pcolormesh(ax=ax[ix],cmap=cmap,levels=clevs,add_colorbar=False)

for ix in range(0,len(Tloc[0:2])):
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')
  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

for ix in range(0,1): 
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label='',fontsize=16)
#

plt.suptitle(f'Shape parameter, year={yearb}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Shape parameter, year=1979')

# %%
## Build colorbar
from matplotlib import cm
clevsa=np.arange(0.06,1.01,0.01)
clevsb=np.arange(0,0.051,0.001)
clevs_pv=np.concatenate((clevsb,clevsa))
cmap = cm.get_cmap('Purples',len(clevsa)+20)
cmaplist = [cmap(i) for i in range(20,cmap.N)]
cmap2 = cm.get_cmap('YlGn_r', len(clevsb)+5)
cmaplist2 = [cmap2(i) for i in range(0,cmap2.N-5)]

pvalue_cmap = colors.LinearSegmentedColormap.from_list('Custom cmap',\
                cmaplist2+cmaplist, len(cmaplist2)+len(cmaplist))

# %%
proj=ccrs.PlateCarree()

fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.25,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.01)
ax = ax.flatten()
for ix in range(0,len(Tloc)): 
  cc = Tpvalue[ix].plot.pcolormesh(ax=ax[ix],cmap=pvalue_cmap,levels=clevs_pv,add_colorbar=False)

for ix in range(0,len(Tloc)):
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')
  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

for ix in range(0,1): 
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label='',fontsize=16)
#

plt.suptitle(f'p-value of N-S hypothesis',fontsize=20)
# Out:
# Text(0.5, 0.98, 'p-value of N-S hypothesis')
